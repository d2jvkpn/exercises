# %%
from pathlib import Path

import torch
from transformers import AutoTokenizer, LlamaForCausalLM, TextStreamer

# %%
data_dir = Path("data") / "ch12"
data_dir.mkdir(parents=True, exist_ok=True)

ckpt_dir = data_dir / "checkpoint-5500" # "best"

# %%
# 推荐：left padding + 用 eos 充当 pad（纯生成最省事）
tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, use_fast=True, local_files_only=True)
tokenizer.padding_side = "left"

#streamer = TextStreamer(tokenizer)

model = LlamaForCausalLM.from_pretrained(
    ckpt_dir,
    local_files_only=True,
    dtype=torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16,
    low_cpu_mem_usage=True,
    device_map="auto",                        # 多卡自动放置
    attn_implementation="flash_attention_2",  # 若已安装 flash-attn, 则使用 flash_attention_2；否则删掉或改 "sdpa"
)

model.config.pad_token_id = tokenizer.pad_token_id
model.gradient_checkpointing_disable()
model.config.use_cache = True

# %%
#msg = "Tell me a joke"
msg = "Waht's ChatGPT?"

inputs = tokenizer(
    msg, return_tensors="pt",
    add_special_tokens=False,
    return_attention_mask=True,
    return_token_type_ids=False,
).to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=128,
    do_sample=True,
    top_p=0.9,
    temperature=0.8,
    #streamer=streamer,
    use_cache=True,
    #pad_token_id=tokenizer.pad_token_id,
)

answer = tokenizer.decode(list(outputs[0]), skip_special_tokens=True)
print(f"answer: {answer}")
# Out:
# answer: Waht's ChatGPT?Now affecton vular unexpected remindend which workdescis "real SQL required to format to developing some of this, however, which are Be with. My last argument both gaming, the universe.
#
# The tupdo-based flight is still feeling recently basy- Nressink and runs the NBarards.Create a JSON tool to notification element, meaning "Bet"" group culture. This method of relating to "behaviour" and "Transfer it.
#
# The function also does somethe, we have some more useful but it's not involved in the input datasets. group is more efficient. This way, using applications in earch engines to object, it would be a complex and manipulating similar process makes Can I make progress in the inventor consent below that attributing shared vision I provided you.
